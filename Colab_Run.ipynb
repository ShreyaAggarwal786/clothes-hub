# %% [markdown]
# # AI-Stylist: Advanced Virtual Try-On (Colab Edition)
#
# Welcome to **AI-Stylist**! This notebook allows you to run the virtual try-on system directly on Google Colab and access the web interface from anywhere using Gradio's public link feature.
#
# ### 🚀 Step 1: Install Dependencies
# This may take 2-3 minutes. We will install the required libraries and download the model weights automatically.

# %%
# @title Install AI-Stylist Environment
# !pip install -r requirements.txt
# Pre-download the model weights to save time later
from huggingface_hub import snapshot_download
snapshot_download(repo_id="zhengchong/CatVTON")

# %% [markdown]
# ### 🎨 Step 2: Launch AI-Stylist
# Run the cell below to start the Gradio app.
#
# **Important:** Once the app is running, look for a link that says `Running on public URL: https://XXXXX.gradio.live`. Click that link to open the AI-Stylist interface in a new tab!

# %%
# @title Start Web Interface
# !python app.py --output_dir "output" --mixed_precision "bf16" --allow_tf32

# %% [markdown]
# ### 💡 Pro Tips:
# - **Precision:** We use `bf16` precision to fit the high-resolution model (1024x768) into Colab's T4 GPU memory.
# - **Output:** Generated images will be saved in the `output` folder in this session.
# - **Safety:** The SafetyChecker is enabled by default to ensure appropriate content generation.
